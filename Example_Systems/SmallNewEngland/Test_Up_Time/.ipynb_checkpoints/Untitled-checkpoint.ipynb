# %%
using Revise

# %%
include("Run.jl")
# Out:
# Loading packages
# Configuring Solver
# Loading Inputs
# Reading Input CSV Files
# Load_data.csv Successfully Read!
# Fuels_data.csv Successfully Read!
# Generators_data.csv Successfully Read!
# Generators_variability.csv Successfully Read!
# CSV Files Successfully Read In From /home/jacob/Downloads/Simple_Test_Case_Modified
# Generating the Optimization Model
# Academic license - for non-commercial use only
# Discharge Module
# Non-served Energy Module
# Investment Discharge Module
# Unit Commitment Module
# Emissions Module (for CO2 Policy modularization
# Dispatchable Resources Module
# Storage Resources Module
# Storage Investment Module
# Storage Core Resources Module
# Storage Resources with Symmetric Charge/Discharge Capacity Module
# Thermal (Unit Commitment) Resources Module
# C02 Policies Module
# Solving Model
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (linux64)
# Optimize a model with 486 rows, 222 columns and 1468 nonzeros
# Model fingerprint: 0x27f1ca83
# Variable types: 149 continuous, 73 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 1.100000e+07
# Presolve removed 422 rows and 166 columns
# Presolve time: 0.00s
# Presolved: 64 rows, 56 columns, 408 nonzeros
# Found heuristic solution: objective 40.0000000
# Variable types: 0 continuous, 56 integer (56 binary)
# Presolved: 64 rows, 56 columns, 408 nonzeros
#
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 6.400e+02
#  Factor NZ  : 1.246e+03
#  Factor Ops : 2.748e+04 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -2.21671957e+04 -1.16648132e+07  5.65e+00 2.69e+05  5.01e+05     0s
#    1  -1.34258006e+05 -5.26025160e+06  6.18e-01 3.63e+04  7.06e+04     0s
#    2   1.53892610e+05 -1.11791086e+06  2.57e-15 3.49e-10  7.57e+03     0s
#    3   1.04114200e+04 -1.49052733e+04  3.12e-14 2.33e-10  1.51e+02     0s
#    4   1.31275401e+02 -9.68748324e+00  8.36e-15 2.82e-10  8.39e-01     0s
#    5   8.90204698e+01  1.51309619e+01  1.77e-13 2.33e-10  4.40e-01     0s
#    6   4.23978349e+01  3.75004265e+01  1.04e-12 1.37e-10  2.92e-02     0s
#
# Barrier performed 6 iterations in 0.00 seconds
# Objective cutoff exceeded
#
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        40.00000   40.00000  0.00%     -    0s
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 40 1.1e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+01, best bound 4.000000000000e+01, gap 0.0000%
#
# User-callback calls 78, time in user-callback 0.00 sec
# MILP solved for primal
# Solving LP solution for duals
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (linux64)
# Optimize a model with 486 rows, 222 columns and 1468 nonzeros
# Model fingerprint: 0x01a98663
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+00]
#   Objective range  [1e+01, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 486 rows and 222 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.0000000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds
# Optimal objective  4.000000000e+01
#
# User-callback calls 108, time in user-callback 0.00 sec
# Writing Output
# Time elapsed for writing costs is
# 0.000448439
# Time elapsed for writing storage is
# 0.000257063
# Time elapsed for writing nse is
# 0.000640066
# Time elapsed for writing power balance is
# 0.007010893
# Time elapsed for writing emissions is
# 0.000809659
# Time elapsed for writing reliability is
# 0.000237201
# 3Time elapsed for writing storage duals is
# 0.000304962
# Time elapsed for writing commitment is
# 0.000211362
# Time elapsed for writing startup is
# 0.000738471
# Time elapsed for writing shutdown is
# 0.000867228
# Time elapsed for writing time weights is
# 6.1166e-5
# Time elapsed for writing net revenue is
# 0.000504754
# Wrote outputs to /home/jacob/Downloads/Simple_Test_Case_Modified/Results_1
# Time elapsed for writing is
# 0.039245307

# %%
@doc raw"""
    hoursbefore(p::Int, t::Int, b::Int)

Determines the time index b hours before index t in
a landscape starting from t=1 which is separated
into distinct periods of length p.

For example, if p = 10,
1 hour before t=1 is t=10,
1 hour before t=10 is t=9
1 hour before t=11 is t=20
"""
function hoursbefore(p::Int, t::Int, b::Int)::Int
    period = div(t - 1, p)
    return period * p + mod1(t - b, p)
end

@doc raw"""
    hoursbefore(p::Int, t::Int, b::UnitRange)

This is a generalization of hoursbefore(... b::Int)
to allow for example b=1:3 to fetch a Vector{Int} of the three hours before
time index t.
"""
function hoursbefore(p::Int, t::Int, b::UnitRange{Int})::Vector{Int}
    period = div(t - 1, p)
    return period * p .+ mod1.(t .- b, p)
end
# Out:
# hoursbefore
